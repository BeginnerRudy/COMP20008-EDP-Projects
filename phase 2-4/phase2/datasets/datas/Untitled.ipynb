# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from pandas.plotting import parallel_coordinates
import numpy as np
import sklearn 
import scipy.stats as stats

LGA_Labour_Force_2011 = pd.read_csv('LGA_Labour_Force_2011.csv',encoding = 'ISO-8859-1')
LGA_Number_of_Offences_in_Victoria_by_Offence_Type_2011 = pd.read_csv('LGA_Number_of_Offences_in_Victoria_by_Offence_Type_2011.csv',encoding = 'ISO-8859-1')

unemploymentRate = LGA_Labour_Force_2011[' unemploymnt_3_percent_6_12_6_12']
unemploymentNum = LGA_Labour_Force_2011['unemploymnt_2_denom_6_12_6_12']
CrimeNum = LGA_Number_of_Offences_in_Victoria_by_Offence_Type_2011[' grand_total_offence_count']
ACrimeNum = LGA_Number_of_Offences_in_Victoria_by_Offence_Type_2011[' total_division_a_offences']
BCrimeNum = LGA_Number_of_Offences_in_Victoria_by_Offence_Type_2011[' total_division_b_offences']
CCrimeNum = LGA_Number_of_Offences_in_Victoria_by_Offence_Type_2011[' total_division_c_offences']
DCrimeNum = LGA_Number_of_Offences_in_Victoria_by_Offence_Type_2011[' total_division_d_offences']
RobberyNum =  LGA_Number_of_Offences_in_Victoria_by_Offence_Type_2011[' a50_robbery']
TheftNum =  LGA_Number_of_Offences_in_Victoria_by_Offence_Type_2011[' b40_theft']
Population = LGA_Number_of_Offences_in_Victoria_by_Offence_Type_2011[' lga_erp']
CrimeRate = CrimeNum/Population
RobberyRate = RobberyNum/Population
ACrimeRate = ACrimeNum/Population
BCrimeRate = BCrimeNum/Population
CCrimeRate = CCrimeNum/Population
DCrimeRate = DCrimeNum/Population
EmploymentRate =  LGA_Labour_Force_2011[' lab_force_3_percent_6_12_6_12']
EmploymentNum =  LGA_Labour_Force_2011[' lab_force_1_no_6_12_6_12']

# %%
plt.scatter(unemploymentRate.iloc[0:79], CrimeNum)

# %%
plt.scatter(unemploymentRate.iloc[0:79], ACrimeNum)

# %%
plt.scatter(unemploymentRate.iloc[0:79], BCrimeNum)

# %%
plt.scatter(unemploymentRate.iloc[0:79], CCrimeNum)

# %%
plt.scatter(unemploymentRate.iloc[0:79], DCrimeNum)

# %%
plt.scatter(unemploymentRate.iloc[0:79], RobberyNum)

# %%
plt.scatter(unemploymentRate.iloc[0:79], TheftNum)

# %%
plt.scatter(unemploymentNum.iloc[0:79], CrimeNum, marker = '+')

# %%
plt.scatter(unemploymentRate.iloc[0:79], CrimeRate)

# %%
plt.scatter(unemploymentRate.iloc[0:79], RobberyRate)

# %%
plt.scatter(unemploymentRate.iloc[0:79], TheftRate)

# %%
plt.scatter(unemploymentRate.iloc[0:79], ACrimeRate)

# %%
plt.scatter(unemploymentRate.iloc[0:79], BCrimeRate)

# %%
plt.scatter(unemploymentRate.iloc[0:79], CCrimeRate)

# %%
plt.scatter(unemploymentRate.iloc[0:79], DCrimeRate)

# %%
plt.scatter(EmploymentRate.iloc[0:79], CrimeRate)

# %%
data = pd.DataFrame({'x': EmploymentRate.iloc[0:79], 'y':CrimeRate })
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

model.fit(data, data['y'])

# plt.scatter(x, y)
# plt.plot(xfit, yfit);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-ca9bba8c4f6e> in <module>()
#       6
#       7 xfit = np.linspace(0, 10, 1000)
# ----> 8 yfit = model.predict(xfit[:, np.newaxis])
#       9
#      10 # plt.scatter(x, y)
#
# C:\software\anaconda\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# C:\software\anaconda\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     239         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     240         return safe_sparse_dot(X, self.coef_.T,
# --> 241                                dense_output=True) + self.intercept_
#     242
#     243     def predict(self, X):
#
# ...

# %%
plt.plot(EmploymentRate.iloc[0:79])

# %%
from scipy.stats import linregress

Info = linregress(EmploymentRate.iloc[0:79], CrimeRate)

# %%
print("Pearson r is ",EmploymentRate.iloc[0:79].corr(CrimeRate))
# Out:
# Pearson r is  -0.1157302505023409

# %%
def abline(slope, intercept):
    """Plot a line from slope and intercept"""
    axes = plt.gca()
    x_vals = np.array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, '-')
plt.scatter(EmploymentRate.iloc[0:79], CrimeRate)
abline(Info[0], Info[1])

# %%
df1 = pd.DataFrame({'x': EmploymentRate.iloc[0:79], 'y':CrimeRate })
df1.corr()
# plt.matshow(df1.corr())
# Out:
#          x        y
# x  1.00000 -0.11573
# y -0.11573  1.00000
